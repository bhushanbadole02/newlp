# %% [markdown]
# <a href="https://colab.research.google.com/github/bhushanbadole02/newlp/blob/main/a4normsymmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
# Step 1: Create a sample dataset
np.random.seed(42)
x = np.random.uniform(1, 50, 50)
y = 2 * x + np.random.normal(0, 10, 50)

df = pd.DataFrame({'X': x, 'Y': y})

# %%
# Step 2: Scatter Plot
plt.scatter(df['X'], df['Y'])
plt.title("Scatter Plot of X vs Y")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Step 3: Histogram for Normality (Graph Method)
plt.hist(df['Y'], bins=10, edgecolor='black')
plt.title("Histogram of Y")
plt.xlabel("Y values")
plt.ylabel("Frequency")
plt.show()

# %%
# Step 4: Q-Q Plot for Normality
stats.probplot(df['Y'], dist="norm", plot=plt)
plt.title("Q-Q Plot of Y")
plt.show()

# %%
# Step 5: Shapiro–Wilk Normality Test
shapiro_stat, shapiro_p = stats.shapiro(df['Y'])
print("Shapiro-Wilk Test:")
print("Statistic:", shapiro_stat)
print("p-value:", shapiro_p)
# Out:
# Shapiro-Wilk Test:
# Statistic: 0.9613576740157717
# p-value: 0.1013387701336298

# %%
# Step 6: Symmetry Test using Skewness
skew_value = stats.skew(df['Y'])
print("\nSkewness of Y:", skew_value)
# Out:
# Skewness of Y: 0.3087738400543275

# %%
# Step 7: Spearman’s Rank Correlation
spearman_corr, spearman_p = stats.spearmanr(df['X'], df['Y'])
print("\nSpearman's Rank Correlation:")
print("Correlation coefficient:", spearman_corr)
print("p-value:", spearman_p)
# Out:
# Spearman's Rank Correlation:
# Correlation coefficient: 0.9451620648259302
# p-value: 5.693840736734238e-25
